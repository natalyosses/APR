# %%
# libreria para trabajar con mapas 
import folium 
import pandas as pd

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Aca estoy cargando el set de datos que subi a la carpeta.
datos = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)

#Valdivia
datos_nombres_valdivia=list(datos.iloc[1963:1977,12])
datos_lat_valdivia=datos.iloc[1963:1977,19] 
datos_long_valdivia=datos.iloc[1963:1977,18]

#Paillaco
datos_nombres_paillaco=list(datos.iloc[1919:1930,12])
datos_lat_paillaco=datos.iloc[1919:1930,19] 
datos_long_paillaco=datos.iloc[1919:1930,18]

#Los Lagos
datos_nombres_loslagos=list(datos.iloc[1885:1903,12])
datos_lat_loslagos=datos.iloc[1885:1903,19] 
datos_long_loslagos=datos.iloc[1885:1903,18]

#Corral
datos_nombres_corral=list(datos.iloc[1873:1879,12])
datos_lat_corral=datos.iloc[1873:1879,19] 
datos_long_corral=datos.iloc[1873:1879,18]

#Creación del par de coordenadas
locations_valdivia = list(zip(datos_lat_valdivia, datos_long_valdivia))
locations_paillaco = list(zip(datos_lat_paillaco, datos_long_paillaco))
locations_loslagos = list(zip(datos_lat_loslagos, datos_long_loslagos))
locations_corral = list(zip(datos_lat_corral, datos_long_corral))


#Creación de las listas
nombres = datos_nombres_valdivia+datos_nombres_paillaco+datos_nombres_loslagos+datos_nombres_corral
locations=locations_valdivia+locations_paillaco+locations_loslagos+locations_corral

#Aca agregamos un marcador con la ubicación de valdivia
for i in range(len(locations)):
    nombre=nombres[i]
    folium.Marker(location=locations[i],tooltip=nombre).add_to(map)
    
for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map

# Aca estoy agregando un minimap en la esquina,para esto hay que cargar la funcion plugins desde la libreria folium
from folium import plugins
minimap = plugins.MiniMap()
map.add_child(minimap)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6ddca1282e973f53a289f2a9c04a7d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6ddca1282e973f53a289f2a9c04a7d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b6ddca1282e973f53a289f2a9c04a7d1 = L.map(
#                 &quot;map_b6ddca1282e973f53a289f2a9c04a7d1&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04f0ce88d40db633047c1383b06f2be4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             var marker_19834d3ff84a86736fb618c7664297ca = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_19834d3ff84a86736fb618c7664297ca.bindTooltip(
#                 `&lt;div&gt;
#                      PISHUINCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ad83b65ff1b0c909fe72b95d620a531 = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_3ad83b65ff1b0c909fe72b95d620a531.bindTooltip(
#                 `&lt;div&gt;
#                      CURIÑANCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6c16163124da0c6bba9a13b331d58e0e = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_6c16163124da0c6bba9a13b331d58e0e.bindTooltip(
#                 `&lt;div&gt;
#                      HUELLELHUE
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4aa603343ad72bc7dfc0bd5c3094b60d = L.marker(
#                 [-39.8715639883, -73.1852346315],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_4aa603343ad72bc7dfc0bd5c3094b60d.bindTooltip(
#                 `&lt;div&gt;
#                      LAS GAVIOTAS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ce84d64a855882033724ac835bcb4f56 = L.marker(
#                 [-39.8547751549, -73.3907718436],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_ce84d64a855882033724ac835bcb4f56.bindTooltip(
#                 `&lt;div&gt;
#                      NIEBLA-LOS MOLINOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5107a8467c152e0c5feb691659058074 = L.marker(
#                 [-39.7603001637, -73.2705681336],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_5107a8467c152e0c5feb691659058074.bindTooltip(
#                 `&lt;div&gt;
#                      PUNUCAPA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e62fe5900774a2974264cb2a87d534d9 = L.marker(
#                 [-39.831480037, -73.4025892212],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_e62fe5900774a2974264cb2a87d534d9.bindTooltip(
#                 `&lt;div&gt;
#                      SAN IGNACIO-PLAYA ROSADA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2933133a08b77d39374f210e43a96540 = L.marker(
#                 [-39.8649364171, -73.3728400295],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_2933133a08b77d39374f210e43a96540.bindTooltip(
#                 `&lt;div&gt;
#                      TRES ESPINOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fc4cc37cbd64354ded6e436dc8f6e5bc = L.marker(
#                 [-39.7314121294, -73.1091043702],
#                 {}
#             ).addTo(map_b6ddca1282e973f53a289f2a9c04a7d1);
#
#
#             marker_fc4cc37cbd64354ded6e436dc8f6e5bc.bindTooltip(
#                 `&lt;div&gt;
#                      VILLA CAYUMAPU
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;:

# %%
from folium import plugins
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Recopilación de datos
datos_beneficiarios_valdivia=list(datos.iloc[1963:1977,9])
datos_beneficiarios_paillaco=list(datos.iloc[1919:1930,9])
datos_beneficiarios_loslagos=list(datos.iloc[1885:1903,9])
datos_beneficiarios_corral=list(datos.iloc[1873:1879,9])

beneficiarios = datos_beneficiarios_valdivia+datos_beneficiarios_paillaco+datos_beneficiarios_loslagos+datos_beneficiarios_corral

colormap = folium.StepColormap(colors=['green','yellow','orange','red','purple'] ,
                           index=[121,298,546,964,2294,4021],
                           vmin= 121,
                           vmax=4021)
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)
for i in range(len(locations)):
    folium.Circle(location=locations[i],radius=250,color=colormap(beneficiarios[i]),).add_to(map)
    nombre=nombres[i]
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4bd122bee5851b470f04357bc34a09a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4bd122bee5851b470f04357bc34a09a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4bd122bee5851b470f04357bc34a09a = L.map(
#                 &quot;map_c4bd122bee5851b470f04357bc34a09a&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a65fb56d17e3ad6054e0be6a53287445 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_90308bda21910d0d6db978b1d22b1528 = L.circle(
#                 [-39.8062305249, -73.0547464487],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_30d3c36655f3c68d4ada9b40e7988c70 = L.circle(
#                 [-39.7283824204, -73.3948919817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_26ee9d27e14764c4cdb33aa2df097f35 = L.circle(
#                 [-39.7930844112, -73.124067117],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_6e1afd095dcb84fc9e31640a4e068309 = L.circle(
#                 [-39.8715639883, -73.1852346315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_7ed26acbecbbbb9f088f9ea8cf84d22e = L.circle(
#                 [-39.8547751549, -73.3907718436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800080ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#800080ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_80a792fed0573e0fdc93ab564f2fb49b = L.circle(
#                 [-39.7603001637, -73.2705681336],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c4bd122bee5851b470f04357bc34a09a);
#
#
#             var circle_63251fbcdca15689b085bb1eb0e2371d = L.circle(
#                 [-39.831480037, -73.4025892212],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&

# %%
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

color_beneficiario=[]

for j in range(len(locations)):
    u=beneficiarios[j]
    if u<299:
        colores='darkred'
    if u>=299 and u<546:
        colores='green'
    if u>=546 and u<964:
        colores='orange'
    if u>=964 and u<2294:
        colores='red'               
    if u>=2294:
        colores='purple'
    color_beneficiario.append(colores)
    folium.Marker(
    location=locations[j],
    popup="Punto",
    tooltip=nombres[j],
    icon=folium.Icon(color=colores),
).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac508973a480b9b9e5b1da0081ed9021 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac508973a480b9b9e5b1da0081ed9021&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ac508973a480b9b9e5b1da0081ed9021 = L.map(
#                 &quot;map_ac508973a480b9b9e5b1da0081ed9021&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_806cc9aa513bd32895ae563e685efb48 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac508973a480b9b9e5b1da0081ed9021);
#
#
#             var marker_cf499c8ada806fb299ce9d9e6302da96 = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_ac508973a480b9b9e5b1da0081ed9021);
#
#
#             var icon_346aaab4aa0623848923bd16ef478900 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf499c8ada806fb299ce9d9e6302da96.setIcon(icon_346aaab4aa0623848923bd16ef478900);
#
#
#         var popup_6f248422be25c83818df4743b2289580 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3b76c83306f3e0314dd5a01775177178 = $(`&lt;div id=&quot;html_3b76c83306f3e0314dd5a01775177178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_6f248422be25c83818df4743b2289580.setContent(html_3b76c83306f3e0314dd5a01775177178);
#
#
#         marker_cf499c8ada806fb299ce9d9e6302da96.bindPopup(popup_6f248422be25c83818df4743b2289580)
#         ;
#
#
#
#
#             marker_cf499c8ada806fb299ce9d9e6302da96.bindTooltip(
#                 `&lt;div&gt;
#                      PISHUINCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e27145ca15037b08fd4106ef1ebf244 = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_ac508973a480b9b9e5b1da0081ed9021);
#
#
#             var icon_97d6c1897bb180f82f2fc5c707538da6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7e27145ca15037b08fd4106ef1ebf244.setIcon(icon_97d6c1897bb180f82f2fc5c707538da6);
#
#
#         var popup_8e4fd4bd0f238747ffd4fa308bceefba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e042ddb4b6b86c3843b7a7724d098601 = $(`&lt;div id=&quot;html_e042ddb4b6b86c3843b7a7724d098601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_8e4fd4bd0f238747ffd4fa308bceefba.setContent(html_e042ddb4b6b86c3843b7a7724d098601);
#
#
#         marker_7e27145ca15037b08fd4106ef1ebf244.bindPopup(popup_8e4fd4bd0f238747ffd4fa308bceefba)
#         ;
#
#
#
#
#             marker_7e27145ca15037b08fd4106ef1ebf244.bindTooltip(
#                 `&lt;div&gt;
#                      CURIÑANCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f4eb5e0b6eb6670c218bcf0f7536cf71 = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_ac508973a480b9b9e5b1da0081ed9021);
#
#
#             var icon_2f3710f4479e770665048b29594d1440 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f4eb5e0b6eb6670c218bcf0f7536cf71.setIcon(icon_2f3710f4479e770665048b29594d1440);
#
#
#         var popup_8f25b73045daebcbc34a8c73705f2cfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1ce0319c59e359f3ceeb91dff74c7512 = $(`&lt;div id=&quot;html_1ce0319c59e359f3ceeb91dff74c7512&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_8f25b73045daebcbc34a8c73705f2cfe.setContent(html_1ce0319c59e359f3ceeb91dff74c7512);
#
#
#         marker_f4eb5e0b6eb6670c218bcf0f7536cf71.bindPopup(popup_8f25b73045daebcbc34a8c73705f2cfe)
#         ;
#
#
#
#
#             marker_f4eb5e0b6eb6670c218bcf0f7536cf71.bindTooltip(
#                 `&lt;div&gt;
#                      HUELLELHUE
#                  &lt

# %%
import pandas as pd
tabla = pd.DataFrame()
tabla['Nombre Ubicación'] = None
tabla['Beneficiarios']=None
tabla['Color']=None

tabla['Nombre Ubicación'] = nombres
tabla['Beneficiarios'] = beneficiarios
tabla['Color'] = color_beneficiario

print(tabla)
# Out:
#             Nombre Ubicación  Beneficiarios    Color
# 0                  PISHUINCO          322.0    green
# 1                  CURIÑANCO         2294.0   purple
# 2                 HUELLELHUE          310.0    green
# 3               LAS GAVIOTAS         1048.0      red
# 4         NIEBLA-LOS MOLINOS         4021.0   purple
# 5                   PUNUCAPA          459.0    green
# 6   SAN IGNACIO-PLAYA ROSADA          936.0   orange
# 7               TRES ESPINOS         1091.0      red
# 8             VILLA CAYUMAPU         1327.0      red
# 9     EL ARENAL SANTA ELVIRA          549.0   orange
# 10                   PAILLAO          871.0   orange
# 11               CABO BLANCO          543.0    green
# 12            EL ARENAL KM 2          623.0   orange
# 13                 Chabelita          434.0    green
# 14                 ARCO IRIS          394.0    green
# 15                 EL LLOLLY          428.0    green
# 16             PICHIRROPULLI         1079.0      red
# 17                    REUMEN         1442.0      red
# 18            SANTA FILOMENA          403.0    green
# 19                     MANAO          220.0  darkred
# 20          SANTA ROSA CHICA          394.0    green
# 21         SANTA ROSA GRANDE          319.0    green
# 22           LUMACO PAILLACO          710.0   orange
# 23                 EL MAITEN          155.0  darkred
# 24         SANTA FILOMENA II          211.0  darkred
# 25                  ANTILHUE         1414.0      red
# 26         FOLILCO LOS LAGOS          474.0    green
# 27                QUILQUILCO          149.0  darkred
# 28                   RIÑIHUE          208.0  darkred
# 29                  USTARITZ          434.0    green
# 30                  EL SALTO          592.0   orange
# 31  PELLINADA LAS QUINIENTAS          434.0    green
# 32                    PANCUL          729.0   orange
# 33              LOS COLIGÜES          456.0    green
# 34                 COLO COLO          298.0  darkred
# 35              LAS HUELLLAS          276.0  darkred
# 36                 San Pedro          375.0    green
# 37                       NaN          434.0    green
# 38                       NaN          208.0  darkred
# 39                       NaN          236.0  darkred
# 40                       NaN           71.0  darkred
# 41                       NaN           81.0  darkred
# 42                       NaN           78.0  darkred
# 43         AMARGO-SAN CARLOS         2412.0   purple
# 44              ISLA DEL REY          620.0   orange
# 45              ISLA MANCERA          267.0  darkred
# 46                 LA AGUADA          626.0   orange
# 47                  CHAIHUIN          744.0   orange
# 48          CERROS DE CORRAL          484.0    green

# %%
import plotly.express as px
#Aca estamos llamando al set de datos de la tabla,que viene precargado en la librería

fig = px.bar(tabla, x="Nombre Ubicación", y="Beneficiarios",color="Nombre Ubicación",
             title="Beneficiarios por sector de instalación de APR",
             color_discrete_sequence=color_beneficiario)
fig.show()
