# %%
# libreria para trabajar con mapas 
import folium

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Aca se crea la variable etiqueta,para posicionarla sobre el punto
etiqueta1 = "Sistema APR Pishuinco"
etiqueta2 = "Siatema APR Curiñanco"
etiqueta3 = "Siatema APR Huellenhue"
etiqueta4 = "Sistema APR Las Gaviotas"
etiqueta5 = "Siatema APR Niebla - Los Molinos"
etiqueta6 = "Siatema APR Punucapa"
etiqueta7 = "Sistema APR San Ignacio - Playa Rosada"
etiqueta8 = "Siatema APR Tres Espinos"
etiqueta9 = "Siatema APR Villa Cayumapu"
etiqueta10 = "Sistema APR El Arenal Santa Elvira"
etiqueta11 = "Siatema APR Paillao"
etiqueta12 = "Siatema APR Cabo Blanco"
etiqueta13 = "Siatema APR El Arenal KM 2"
etiqueta14 = "Siatema APR Chabelita"

#Aca agregamos un marcador con la ubicación de valdivia
folium.Marker([-39.8062305249,-73.0547464487], popup="<i>Punto de prueba</i>", tooltip=etiqueta1).add_to(map)
folium.Marker([-39.7283824204,-73.3948919817], popup="<i>Punto de prueba2</i>", tooltip=etiqueta2).add_to(map)
folium.Marker([-39.7930844112,-73.124067117], popup="<i>Punto de prueba3</i>", tooltip=etiqueta3).add_to(map)
folium.Marker([-39.8715639883,-73.1852346315], popup="<i>Punto de prueba4</i>", tooltip=etiqueta4).add_to(map)
folium.Marker([-39.8547751549,-73.3907718436], popup="<i>Punto de prueba5</i>", tooltip=etiqueta5).add_to(map)
folium.Marker([-39.7603001637,-73.2705681336], popup="<i>Punto de prueba6</i>", tooltip=etiqueta6).add_to(map)
folium.Marker([-39.831480037,-73.4025892212], popup="<i>Punto de prueba7</i>", tooltip=etiqueta7).add_to(map)
folium.Marker([-39.8649364171,-73.3728400295], popup="<i>Punto de prueba8</i>", tooltip=etiqueta8).add_to(map)
folium.Marker([-39.7314121294,-73.1091043702], popup="<i>Punto de prueba9</i>", tooltip=etiqueta9).add_to(map)
folium.Marker([-39.772903642,-73.1970058325], popup="<i>Punto de prueba10</i>", tooltip=etiqueta10).add_to(map)
folium.Marker([-39.8673123199,-73.2088638403], popup="<i>Punto de prueba11</i>", tooltip=etiqueta11).add_to(map)
folium.Marker([-39.7802702288,-73.2412708338], popup="<i>Punto de prueba12</i>", tooltip=etiqueta12).add_to(map)
folium.Marker([-39.7737197231,-73.2102553189], popup="<i>Punto de prueba13</i>", tooltip=etiqueta13).add_to(map)
folium.Marker([-39.7772055631,-73.3135380035], popup="<i>Punto de prueba13</i>", tooltip=etiqueta14).add_to(map)
map

# Aca estoy agregando un minimap en la esquina,para esto hay que cargar la funcion plugins desde la libreria folium
from folium import plugins
minimap = plugins.MiniMap()
map.add_child(minimap)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Aca estoy cargando el archivo excel completo,para eso primero cargo la libreria pandas
#si no la tienes --> py -m pip install pandas, despues te podria lanzar algun error entonces tambien instala py -m pip install openpyxl
import pandas as pd

#Aca estoy cargando el set de datos que subi a la carpeta.
df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
df
# Out:
#         N°                                Región         Provincia  \
# 0     1606                    Arica Y Parinacota             Arica
# 1     1616                    Arica Y Parinacota             Arica
# 2     1617                    Arica Y Parinacota             Arica
# 3     1628                    Arica Y Parinacota             Arica
# 4     1630                    Arica Y Parinacota             Arica
# ...    ...                                   ...               ...
# 2234  1432  Magallanes y de La Antártica Chilena  Última Esperanza
# 2235  1433  Magallanes y de La Antártica Chilena  Última Esperanza
# 2236  1434  Magallanes y de La Antártica Chilena  Última Esperanza
# 2237  1437  Magallanes y de La Antártica Chilena  Última Esperanza
# 2238  1435  Magallanes y de La Antártica Chilena  Última Esperanza
#
#                 Comuna                            Nombre  oficial sistema  \
# 0                Arica               Comité De Agua Potable Rural De Acha
# ...
