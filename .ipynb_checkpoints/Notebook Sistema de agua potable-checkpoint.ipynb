# %%
# libreria para trabajar con mapas 
import folium

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Aca estoy cargando el set de datos que subi a la carpeta.
df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
df

df_lat=df.iloc[1963:1977,19] 
df_long=df.iloc[1963:1977,18]

df_nombres=df.iloc[1963:1977,12]
df_nombres

nombres = list(zip(df_nombres))
nombres

locations = list(zip(df_lat, df_long))
locations

#Aca se crea la variable etiqueta,para posicionarla sobre el punto
#etiqueta1 = "Sistema APR Pishuinco"
#etiqueta2 = "Sistema APR Curiñanco"
#etiqueta3 = "Sistema APR Huellenhue"
#etiqueta4 = "Sistema APR Las Gaviotas"
#etiqueta5 = "Sistema APR Niebla - Los Molinos"
#etiqueta6 = "Sistema APR Punucapa"
#etiqueta7 = "Sistema APR San Ignacio - Playa Rosada"
#etiqueta8 = "Sistema APR Tres Espinos"
#etiqueta9 = "Sistema APR Villa Cayumapu"
#etiqueta10 = "Sistema APR El Arenal Santa Elvira"
#etiqueta11 = "Sistema APR Paillao"
#etiqueta12 = "Sistema APR Cabo Blanco"
#etiqueta13 = "Sistema APR El Arenal KM 2"
#etiqueta14 = "Sistema APR Chabelita"

#Aca agregamos un marcador con la ubicación de valdivia
#folium.Marker([-39.8062305249,-73.0547464487], popup="<i>Punto de prueba 1</i>", tooltip=etiqueta1).add_to(map)
#folium.Marker([-39.7283824204,-73.3948919817], popup="<i>Punto de prueba 2</i>", tooltip=etiqueta2).add_to(map)
#folium.Marker([-39.7930844112,-73.124067117], popup="<i>Punto de prueba 3</i>", tooltip=etiqueta3).add_to(map)
#folium.Marker([-39.8715639883,-73.1852346315], popup="<i>Punto de prueba 4</i>", tooltip=etiqueta4).add_to(map)
#folium.Marker([-39.8547751549,-73.3907718436], popup="<i>Punto de prueba 5</i>", tooltip=etiqueta5).add_to(map)
#folium.Marker([-39.7603001637,-73.2705681336], popup="<i>Punto de prueba 6</i>", tooltip=etiqueta6).add_to(map)
#folium.Marker([-39.831480037,-73.4025892212], popup="<i>Punto de prueba 7</i>", tooltip=etiqueta7).add_to(map)
#folium.Marker([-39.8649364171,-73.3728400295], popup="<i>Punto de prueba 8</i>", tooltip=etiqueta8).add_to(map)
#folium.Marker([-39.7314121294,-73.1091043702], popup="<i>Punto de prueba 9</i>", tooltip=etiqueta9).add_to(map)
#folium.Marker([-39.772903642,-73.1970058325], popup="<i>Punto de prueba 10</i>", tooltip=etiqueta10).add_to(map)
#folium.Marker([-39.8673123199,-73.2088638403], popup="<i>Punto de prueba 11</i>", tooltip=etiqueta11).add_to(map)
#folium.Marker([-39.7802702288,-73.2412708338], popup="<i>Punto de prueba 12</i>", tooltip=etiqueta12).add_to(map)
#folium.Marker([-39.7737197231,-73.2102553189], popup="<i>Punto de prueba 13</i>", tooltip=etiqueta13).add_to(map)
#folium.Marker([-39.7772055631,-73.3135380035], popup="<i>Punto de prueba 14</i>", tooltip=etiqueta14).add_to(map)
#map





#Aca agregamos un marcador con la ubicación de valdivia
for i in range(len(locations)):
    nombre=nombres[i]
    folium.Marker(location=locations[i],popup="<i>Punto de prueba</i>",tooltip=nombre).add_to(map)


for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map

# Aca estoy agregando un minimap en la esquina,para esto hay que cargar la funcion plugins desde la libreria folium
from folium import plugins
minimap = plugins.MiniMap()
map.add_child(minimap)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Aca estoy cargando el archivo excel completo,para eso primero cargo la libreria pandas
#si no la tienes --> py -m pip install pandas, despues te podria lanzar algun error entonces tambien instala py -m pip install openpyxl
import pandas as pd

#Aca estoy cargando el set de datos que subi a la carpeta.
#df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
#df

#df_lat=df.iloc[1964:1977,19] 
#df_long=df.iloc[1964:1977,18]

#locations = list(zip(df_lat, df_long))
#locations

# %%
from folium import plugins
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 12)

for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map

colormap = folium.StepColormap(colors=['green','yellow','orange','red'] ,#renkler
                           index=[1,2,3,7,10], #eşik değerler
                           vmin= 1,
                           vmax=10)
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#008000ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...
