# %%
# libreria para trabajar con mapas 
import folium 
import pandas as pd

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Aca estoy cargando el set de datos que subi a la carpeta.
df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
df

df_lat=df.iloc[1963:1977,19] 
df_long=df.iloc[1963:1977,18]

df_nombres=df.iloc[1963:1977,12]
df_nombres

nombres = list(df_nombres)
nombres

locations = list(zip(df_lat, df_long))
locations


#Aca agregamos un marcador con la ubicación de valdivia
for i in range(len(locations)):
    nombre=nombres[i]
    folium.Marker(location=locations[i],popup="<i>Punto de prueba</i>",tooltip=nombre).add_to(map)


for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map

# Aca estoy agregando un minimap en la esquina,para esto hay que cargar la funcion plugins desde la libreria folium
from folium import plugins
minimap = plugins.MiniMap()
map.add_child(minimap)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df0f58c300b737886b75fcaaa512d40a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df0f58c300b737886b75fcaaa512d40a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_df0f58c300b737886b75fcaaa512d40a = L.map(
#                 &quot;map_df0f58c300b737886b75fcaaa512d40a&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a06565af45eff42c689d963fc23fd4e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df0f58c300b737886b75fcaaa512d40a);
#
#
#             var marker_9ac084e728941791b0d5cc92ad039a88 = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_df0f58c300b737886b75fcaaa512d40a);
#
#
#         var popup_e3c2e0e696873cfe5e819c251ba7c040 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a099d07cd651cd6cb9d0ed9c682bc0a1 = $(`&lt;div id=&quot;html_a099d07cd651cd6cb9d0ed9c682bc0a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_e3c2e0e696873cfe5e819c251ba7c040.setContent(html_a099d07cd651cd6cb9d0ed9c682bc0a1);
#
#
#         marker_9ac084e728941791b0d5cc92ad039a88.bindPopup(popup_e3c2e0e696873cfe5e819c251ba7c040)
#         ;
#
#
#
#
#             marker_9ac084e728941791b0d5cc92ad039a88.bindTooltip(
#                 `&lt;div&gt;
#                      PISHUINCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6a62b611f6c692d3d804c3bf87632c54 = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_df0f58c300b737886b75fcaaa512d40a);
#
#
#         var popup_fc8cd5fb3b24849c25e9c3e291c039eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8fde2c7dad191a0ff877756208183e47 = $(`&lt;div id=&quot;html_8fde2c7dad191a0ff877756208183e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_fc8cd5fb3b24849c25e9c3e291c039eb.setContent(html_8fde2c7dad191a0ff877756208183e47);
#
#
#         marker_6a62b611f6c692d3d804c3bf87632c54.bindPopup(popup_fc8cd5fb3b24849c25e9c3e291c039eb)
#         ;
#
#
#
#
#             marker_6a62b611f6c692d3d804c3bf87632c54.bindTooltip(
#                 `&lt;div&gt;
#                      CURIÑANCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7962d940de431e502080f44ad24a53bd = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_df0f58c300b737886b75fcaaa512d40a);
#
#
#         var popup_549ffeeeb0ae7437b6e218b956c6167d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dd9f96809e94b21068e479da2c0a2d16 = $(`&lt;div id=&quot;html_dd9f96809e94b21068e479da2c0a2d16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_549ffeeeb0ae7437b6e218b956c6167d.setContent(html_dd9f96809e94b21068e479da2c0a2d16);
#
#
#         marker_7962d940de431e502080f44ad24a53bd.bindPopup(popup_549ffeeeb0ae7437b6e218b956c6167d)
#         ;
#
#
#
#
#             marker_7962d940de431e502080f44ad24a53bd.bindTooltip(
#                 `&lt;div&gt;
#                      HUELLELHUE
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_882da6588f38d014cc8904dbca05c1fd = L.marker(
#                 [-39.8715639883, -73.1852346315],
#                 {}
#             ).addTo(map_df0f58c300b737886b75fcaaa512d40a);
#
#
#         var popup_ec78283a3d7fe3cfc5d028e804f92e4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7c31070a96aaef387dfef1c626342a5c = $(`&lt;div id=&quot;html_7c31070a96aaef387dfef1c626342a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_ec78283a3d7fe3cfc5d028e804f92e4b.setContent(html_7c31070a96aaef387dfef1c626342a5c);
#
#
#         marker_882da6588f38d014cc8904dbca05c1fd.bindPopup(popup_ec78283a3d7fe3cfc5d028e804f92e4b)
#         ;
#
#
#
#
#             marker_882da6588f38d014cc8904dbca05c1fd.bindTooltip(
#                 `&lt;div&gt;

# %%
# Aca estoy cargando el archivo excel completo,para eso primero cargo la libreria pandas
#si no la tienes --> py -m pip install pandas, despues te podria lanzar algun error entonces tambien instala py -m pip install openpyxl
import pandas as pd

#Aca estoy cargando el set de datos que subi a la carpeta.
#df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
#df

#df_lat=df.iloc[1964:1977,19] 
#df_long=df.iloc[1964:1977,18]

#locations = list(zip(df_lat, df_long))
#locations

# %%
from folium import plugins
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 12)

df_beneficio=df.iloc[1963:1977,9]
beneficio = list(df_beneficio)

colormap = folium.StepColormap(colors=['green','yellow','orange','red','purple'] ,
                           index=[121,298.546,964,2294,4021],
                           vmin= 121,
                           vmax=4021)

colormap

for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fa6c1e07bf667d0b1a65412871edf35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fa6c1e07bf667d0b1a65412871edf35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0fa6c1e07bf667d0b1a65412871edf35 = L.map(
#                 &quot;map_0fa6c1e07bf667d0b1a65412871edf35&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce526fabc7e2934854f7665da265e9ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_9f3591e04bd2430a7ee41467f958d61b = L.circleMarker(
#                 [-39.8062305249, -73.0547464487],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_72db91e1ccebdb44ebafb035b19ec5b0 = L.circleMarker(
#                 [-39.7283824204, -73.3948919817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_90ff6c4b7a110bbf6ea2e3ef21c8fc74 = L.circleMarker(
#                 [-39.7930844112, -73.124067117],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_8e27d120bb32a55e12f4dd0ce80be206 = L.circleMarker(
#                 [-39.8715639883, -73.1852346315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_e4f7d232a90ca3ea9ab02b430dce8675 = L.circleMarker(
#                 [-39.8547751549, -73.3907718436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_8ef7fd960c6a5d88414650b1d844ade6 = L.circleMarker(
#                 [-39.7603001637, -73.2705681336],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fa6c1e07bf667d0b1a65412871edf35);
#
#
#             var circle_marker_44ae6fc6452309f50ea4acc1d65d41e3 = L.circleMarker(
#                 [-39.831480037, -73.4025892212],
