# %%
# libreria para trabajar con mapas 
import folium 
import pandas as pd

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

#Aca estoy cargando el set de datos que subi a la carpeta.
df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
df

df_lat=df.iloc[1963:1977,19] 
df_long=df.iloc[1963:1977,18]

df_nombres=df.iloc[1963:1977,12]
df_nombres

nombres = list(df_nombres)
nombres

locations = list(zip(df_lat, df_long))
locations


#Aca agregamos un marcador con la ubicación de valdivia
for i in range(len(locations)):
    nombre=nombres[i]
    folium.Marker(location=locations[i],popup="<i>Punto de prueba</i>",tooltip=nombre).add_to(map)


for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=5).add_to(map)
map

# Aca estoy agregando un minimap en la esquina,para esto hay que cargar la funcion plugins desde la libreria folium
from folium import plugins
minimap = plugins.MiniMap()
map.add_child(minimap)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c07a120def041b8e378bca7e3875b69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c07a120def041b8e378bca7e3875b69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2c07a120def041b8e378bca7e3875b69 = L.map(
#                 &quot;map_2c07a120def041b8e378bca7e3875b69&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2a109079440ff90ae853e026182c2b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c07a120def041b8e378bca7e3875b69);
#
#
#             var marker_47b3b0826fcd572e885843c1f5d8bc04 = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_2c07a120def041b8e378bca7e3875b69);
#
#
#         var popup_891efa9c1a3531130537d51e79df3000 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1864aaeada3eaa012af1ee54f1a10ec2 = $(`&lt;div id=&quot;html_1864aaeada3eaa012af1ee54f1a10ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_891efa9c1a3531130537d51e79df3000.setContent(html_1864aaeada3eaa012af1ee54f1a10ec2);
#
#
#         marker_47b3b0826fcd572e885843c1f5d8bc04.bindPopup(popup_891efa9c1a3531130537d51e79df3000)
#         ;
#
#
#
#
#             marker_47b3b0826fcd572e885843c1f5d8bc04.bindTooltip(
#                 `&lt;div&gt;
#                      PISHUINCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6125dc5451498b7c2f970f4d9c1a734a = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_2c07a120def041b8e378bca7e3875b69);
#
#
#         var popup_bf00de7e169832e6b357bedcde27e229 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1e5c2e629a49edc15a362a254e8d37d6 = $(`&lt;div id=&quot;html_1e5c2e629a49edc15a362a254e8d37d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_bf00de7e169832e6b357bedcde27e229.setContent(html_1e5c2e629a49edc15a362a254e8d37d6);
#
#
#         marker_6125dc5451498b7c2f970f4d9c1a734a.bindPopup(popup_bf00de7e169832e6b357bedcde27e229)
#         ;
#
#
#
#
#             marker_6125dc5451498b7c2f970f4d9c1a734a.bindTooltip(
#                 `&lt;div&gt;
#                      CURIÑANCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4bde601f948eb82110675874eb633ec6 = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_2c07a120def041b8e378bca7e3875b69);
#
#
#         var popup_9d6637d407844af76ef2ccceba6a869a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_922ade2be406b5b419740bd06ca63fb9 = $(`&lt;div id=&quot;html_922ade2be406b5b419740bd06ca63fb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_9d6637d407844af76ef2ccceba6a869a.setContent(html_922ade2be406b5b419740bd06ca63fb9);
#
#
#         marker_4bde601f948eb82110675874eb633ec6.bindPopup(popup_9d6637d407844af76ef2ccceba6a869a)
#         ;
#
#
#
#
#             marker_4bde601f948eb82110675874eb633ec6.bindTooltip(
#                 `&lt;div&gt;
#                      HUELLELHUE
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_890fb7c0bd630a07f43a17d90140b4c3 = L.marker(
#                 [-39.8715639883, -73.1852346315],
#                 {}
#             ).addTo(map_2c07a120def041b8e378bca7e3875b69);
#
#
#         var popup_d98241389a8943fdc18f680e05e928b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ffca574e8f662a8891dcf14d0cda60ff = $(`&lt;div id=&quot;html_ffca574e8f662a8891dcf14d0cda60ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_d98241389a8943fdc18f680e05e928b1.setContent(html_ffca574e8f662a8891dcf14d0cda60ff);
#
#
#         marker_890fb7c0bd630a07f43a17d90140b4c3.bindPopup(popup_d98241389a8943fdc18f680e05e928b1)
#         ;
#
#
#
#
#             marker_890fb7c0bd630a07f43a17d90140b4c3.bindTooltip(
#                 `&lt;div&gt;

# %%
# Aca estoy cargando el archivo excel completo,para eso primero cargo la libreria pandas
#si no la tienes --> py -m pip install pandas, despues te podria lanzar algun error entonces tambien instala py -m pip install openpyxl
import pandas as pd

#Aca estoy cargando el set de datos que subi a la carpeta.
#df = pd.read_excel('base_ssr.xlsx', sheet_name='Sistemas_APR',usecols="B:U",skiprows=2)
#df

#df_lat=df.iloc[1964:1977,19] 
#df_long=df.iloc[1964:1977,18]

#locations = list(zip(df_lat, df_long))
#locations

# %%
from folium import plugins
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)

df_beneficio=df.iloc[1963:1977,9]
beneficio = list(df_beneficio)

colormap = folium.StepColormap(colors=['green','yellow','orange','red','purple'] ,
                           index=[121,298,546,964,2294,4021],
                           vmin= 121,
                           vmax=4021)
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)
for i in range(len(locations)):
    folium.Circle(location=locations[i],radius=100,color=colormap(beneficio[i]),).add_to(map)
    nombre=nombres[i]
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5416d85ead7b144fa5e5ecc4d85ec633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5416d85ead7b144fa5e5ecc4d85ec633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5416d85ead7b144fa5e5ecc4d85ec633 = L.map(
#                 &quot;map_5416d85ead7b144fa5e5ecc4d85ec633&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d4cbebefcc567e50d915d3b7173dbea = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_a723225a6d40f455becbc02aac25e163 = L.circle(
#                 [-39.8062305249, -73.0547464487],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_5de7ccd1bb06f5f52fb3762545d1adab = L.circle(
#                 [-39.7283824204, -73.3948919817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_b5ab5fa1eb0f38f85a1b6bf575be7abd = L.circle(
#                 [-39.7930844112, -73.124067117],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_98930f287ca967ed864bc631476ea59a = L.circle(
#                 [-39.8715639883, -73.1852346315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_8c2d302cbd667e428862f63ed9c7acb9 = L.circle(
#                 [-39.8547751549, -73.3907718436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800080ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#800080ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_41282a7b9923c298b029fc0778f14801 = L.circle(
#                 [-39.7603001637, -73.2705681336],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5416d85ead7b144fa5e5ecc4d85ec633);
#
#
#             var circle_7e1dc4008bf2c9c8afc2ecc1fe42e745 = L.circle(
#                 [-39.831480037, -73.4025892212],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&

# %%
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 11)
for j in range(len(locations)):
    u=beneficio[j]
    if u<299:
        colores='darkgreen'
    if u>298 and u<547:
        colores='green'
    if u>546 and u<965:
        colores='orange'
    if u>964 and u<2295:
        colores='red'               
    if u>2294:
        colores='darkpurple'
    folium.Marker(
    location=locations[j],
    popup="Punto",
    tooltip=nombres[j],
    icon=folium.Icon(color=colores),
).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_117aa9d3116ae7fe37f8121556617989 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_117aa9d3116ae7fe37f8121556617989&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_117aa9d3116ae7fe37f8121556617989 = L.map(
#                 &quot;map_117aa9d3116ae7fe37f8121556617989&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_515adbeaeeb446e7ac7882e6f96794ad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_117aa9d3116ae7fe37f8121556617989);
#
#
#             var marker_baa7a28f615a9be4aaf993863b06aa5a = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_117aa9d3116ae7fe37f8121556617989);
#
#
#             var icon_c719dfd8d6477cbf1989c0c32b3abe74 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_baa7a28f615a9be4aaf993863b06aa5a.setIcon(icon_c719dfd8d6477cbf1989c0c32b3abe74);
#
#
#         var popup_cac6cb84b53126814fce5f715292af8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7096bc690fafd90d79803262f7cb0ff9 = $(`&lt;div id=&quot;html_7096bc690fafd90d79803262f7cb0ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_cac6cb84b53126814fce5f715292af8a.setContent(html_7096bc690fafd90d79803262f7cb0ff9);
#
#
#         marker_baa7a28f615a9be4aaf993863b06aa5a.bindPopup(popup_cac6cb84b53126814fce5f715292af8a)
#         ;
#
#
#
#
#             marker_baa7a28f615a9be4aaf993863b06aa5a.bindTooltip(
#                 `&lt;div&gt;
#                      PISHUINCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6d477617d036e7ff8eea7f675768043c = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_117aa9d3116ae7fe37f8121556617989);
#
#
#             var icon_a84c5ea8dbc4810cf22ca482daacc1de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d477617d036e7ff8eea7f675768043c.setIcon(icon_a84c5ea8dbc4810cf22ca482daacc1de);
#
#
#         var popup_c967e3ae35eb7fbb41edaf4dd41c0e4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e9a28184bcc713aead07cf3b02c2db9 = $(`&lt;div id=&quot;html_0e9a28184bcc713aead07cf3b02c2db9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_c967e3ae35eb7fbb41edaf4dd41c0e4b.setContent(html_0e9a28184bcc713aead07cf3b02c2db9);
#
#
#         marker_6d477617d036e7ff8eea7f675768043c.bindPopup(popup_c967e3ae35eb7fbb41edaf4dd41c0e4b)
#         ;
#
#
#
#
#             marker_6d477617d036e7ff8eea7f675768043c.bindTooltip(
#                 `&lt;div&gt;
#                      CURIÑANCO
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_38bdb2a053f562802004f5a3d7b68390 = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_117aa9d3116ae7fe37f8121556617989);
#
#
#             var icon_030a8dc8caa513b5bce18162fa328cc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38bdb2a053f562802004f5a3d7b68390.setIcon(icon_030a8dc8caa513b5bce18162fa328cc3);
#
#
#         var popup_6396c4589969e81d530e3d12206c48e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d14a3d5897c3c80618a5aaa33e808117 = $(`&lt;div id=&quot;html_d14a3d5897c3c80618a5aaa33e808117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto&lt;/div&gt;`)[0];
#             popup_6396c4589969e81d530e3d12206c48e8.setContent(html_d14a3d5897c3c80618a5aaa33e808117);
#
#
#         marker_38bdb2a053f562802004f5a3d7b68390.bindPopup(popup_6396c4589969e81d530e3d12206c48e8)
#         ;
#
#
#
#
#             marker_38bdb2a053f562802004f5a3d7b68390.bindTooltip(
#                 `&lt;div&gt;
#                      HUELLELHUE
#                  &lt;/d

# %%
#Lista de colores
#  'green', 'gray', 'darkred', 'lightblue', 'lightgray', 'pink', 'darkpurple', 'white', 'orange', 'beige', 
#'cadetblue', 'lightgreen', 'lightred', 'red', 'blue', 'black', 'darkblue', 'darkgreen', 'purple'
