# %%
# libreria para trabajar con mapas 
import folium

# %%
# Primero creamos el mapa con la libreria folium y la funcion Map,tiles es el proveedor del mapa.
#El mapa esta centrado en valdivia
map = folium.Map(location = [-39.81422,-73.24589], tiles = "OpenStreetMap", zoom_start = 14)

#Aca se crea la variable etiqueta,para posicionarla sobre el punto
etiqueta1 = "Sistema APR"
etiqueta2 = "Siatema APR2"
etiqueta3 = "Siatema APR3"
etiqueta4 = "Sistema APR4"
etiqueta5 = "Siatema APR5"
etiqueta6 = "Siatema APR6"
etiqueta7 = "Sistema APR7"
etiqueta8 = "Siatema APR8"
etiqueta9 = "Siatema APR9"
etiqueta10 = "Sistema APR10"
etiqueta11 = "Siatema APR11"
etiqueta12 = "Siatema APR12"
etiqueta13 = "Siatema APR13"

#Aca agregamos un marcador con la ubicación de valdivia
folium.Marker([-39.8062305249,-73.0547464487], popup="<i>Punto de prueba</i>", tooltip=etiqueta1).add_to(map)
folium.Marker([-39.7283824204,-73.3948919817], popup="<i>Punto de prueba2</i>", tooltip=etiqueta2).add_to(map)
folium.Marker([-39.7930844112,-73.124067117], popup="<i>Punto de prueba3</i>", tooltip=etiqueta3).add_to(map)
folium.Marker([-39.8715639883,-73.1852346315], popup="<i>Punto de prueba4</i>", tooltip=etiqueta4).add_to(map)
folium.Marker([-39.8547751549,-73.3907718436], popup="<i>Punto de prueba5</i>", tooltip=etiqueta5).add_to(map)
folium.Marker([-39.7603001637,-73.2705681336], popup="<i>Punto de prueba6</i>", tooltip=etiqueta6).add_to(map)
folium.Marker([-39.831480037,-73.4025892212], popup="<i>Punto de prueba7</i>", tooltip=etiqueta7).add_to(map)
folium.Marker([-39.8649364171,-73.3728400295], popup="<i>Punto de prueba8</i>", tooltip=etiqueta8).add_to(map)
folium.Marker([-39.7314121294,-73.1091043702], popup="<i>Punto de prueba9</i>", tooltip=etiqueta9).add_to(map)
folium.Marker([-39.772903642,-73.1970058325], popup="<i>Punto de prueba10</i>", tooltip=etiqueta10).add_to(map)
folium.Marker([-39.8673123199,-73.2088638403], popup="<i>Punto de prueba11</i>", tooltip=etiqueta11).add_to(map)
folium.Marker([-39.7802702288,-73.2412708338], popup="<i>Punto de prueba12</i>", tooltip=etiqueta12).add_to(map)
folium.Marker([-39.7737197231,-73.2102553189], popup="<i>Punto de prueba13</i>", tooltip=etiqueta13).add_to(map)
folium.Marker([-39.7772055631,-73.3135380035], popup="<i>Punto de prueba13</i>", tooltip=etiqueta13).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22328a670ecb647ef84522aed6892c17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22328a670ecb647ef84522aed6892c17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_22328a670ecb647ef84522aed6892c17 = L.map(
#                 &quot;map_22328a670ecb647ef84522aed6892c17&quot;,
#                 {
#                     center: [-39.81422, -73.24589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec012c3796a0aed4af5b42d4882ad765 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22328a670ecb647ef84522aed6892c17);
#
#
#             var marker_49db1c37ec738efa5eaac6882f3b69a6 = L.marker(
#                 [-39.8062305249, -73.0547464487],
#                 {}
#             ).addTo(map_22328a670ecb647ef84522aed6892c17);
#
#
#         var popup_56a98947280f56f6608431fe90dc6112 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c16c22eac9a3ab621234536c5690e12 = $(`&lt;div id=&quot;html_1c16c22eac9a3ab621234536c5690e12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_56a98947280f56f6608431fe90dc6112.setContent(html_1c16c22eac9a3ab621234536c5690e12);
#
#
#         marker_49db1c37ec738efa5eaac6882f3b69a6.bindPopup(popup_56a98947280f56f6608431fe90dc6112)
#         ;
#
#
#
#
#             marker_49db1c37ec738efa5eaac6882f3b69a6.bindTooltip(
#                 `&lt;div&gt;
#                      Sistema APR
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_685c656d94bd0dfe07808eebdd7b0538 = L.marker(
#                 [-39.7283824204, -73.3948919817],
#                 {}
#             ).addTo(map_22328a670ecb647ef84522aed6892c17);
#
#
#         var popup_edd36a27e4a5f7103760d9acf26dedce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f11e1cb4968f02a9c9a688473db16b0c = $(`&lt;div id=&quot;html_f11e1cb4968f02a9c9a688473db16b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba2&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_edd36a27e4a5f7103760d9acf26dedce.setContent(html_f11e1cb4968f02a9c9a688473db16b0c);
#
#
#         marker_685c656d94bd0dfe07808eebdd7b0538.bindPopup(popup_edd36a27e4a5f7103760d9acf26dedce)
#         ;
#
#
#
#
#             marker_685c656d94bd0dfe07808eebdd7b0538.bindTooltip(
#                 `&lt;div&gt;
#                      Siatema APR2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3fe185aa23163689f7a4f88938339bc = L.marker(
#                 [-39.7930844112, -73.124067117],
#                 {}
#             ).addTo(map_22328a670ecb647ef84522aed6892c17);
#
#
#         var popup_834c5d83adc77fd22d5852d3dd57259c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2af3356d2011cb7d7ceffe3e7f2320a4 = $(`&lt;div id=&quot;html_2af3356d2011cb7d7ceffe3e7f2320a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba3&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_834c5d83adc77fd22d5852d3dd57259c.setContent(html_2af3356d2011cb7d7ceffe3e7f2320a4);
#
#
#         marker_c3fe185aa23163689f7a4f88938339bc.bindPopup(popup_834c5d83adc77fd22d5852d3dd57259c)
#         ;
#
#
#
#
#             marker_c3fe185aa23163689f7a4f88938339bc.bindTooltip(
#                 `&lt;div&gt;
#                      Siatema APR3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5a79f7d3ef6397a42731a9340d06562f = L.marker(
#                 [-39.8715639883, -73.1852346315],
#                 {}
#             ).addTo(map_22328a670ecb647ef84522aed6892c17);
#
#
#         var popup_d5a33bea3a790576f82ea3ba42b983cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dd51449aae23af869103e8056ea18b7b = $(`&lt;div id=&quot;html_dd51449aae23af869103e8056ea18b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Punto de prueba4&lt;/i&gt;&lt;/div&gt;`)[0];
#             popup_d5a33bea3a790576f82ea3ba42b983cb.setContent(html_dd51449aae23af869103e8056ea18b7b);
#
#
#         marker_5a79f7d3ef6397a42731a9340d06562f.bindPopup(popup_d5a33bea3a790576f82ea3ba42b983cb)
#         ;
#
#
#
#
#             marker_5a79f7d3ef6397a42731a9340d06562f.bindTooltip(
#                 `&lt;div&gt;
#                      Sistema APR4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2eb8789e1e94b41ace33ef2370a2ea8d = L.marker(
#                 [-39.8547751549, -73.3907718436],
#                 {}
